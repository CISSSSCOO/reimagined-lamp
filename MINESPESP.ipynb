# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dluklFgVG4xiJ883GBikXY0O2P_262RkemdcwEca5TqKDzNf" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    ops.json	       user_jvm_args.txt
# banned-players.json  forge.jar.log  patchouli_books    usercache.json
# colabconfig.json     journeymap     run.bat	       usernamecache.json
# config		     libraries	    run.sh	       whitelist.json
# defaultconfigs	     logs	    schematics	       world
# emotes		     mod_data	    scripts
# eula.txt	     mods	    server.properties
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 4.tcp.ngrok.io:12275
# Estas jugando a minecraft: forge en su version: 1.20.1
# La versión de Forge es: 1.20.1-47.2.20
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.20.1-47.2.20/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [14:03:10] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412]
# [14:03:10] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [14:03:23] [main/INFO] [ne.mi.fm.lo.ImmediateWindowHandler/]: ImmediateWindowProvider not loading because launch target is forgeserver
# [14:03:23] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2365!/ Service=ModLauncher Env=SERVER
# [14:03:23] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.20.1-47.2.20/fmlcore-1.20.1-47.2.20.jar is missing mods.toml file
# [14:03:23] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.20.1-47.2.20/javafmllanguage-1.20.1-47.2.20.jar is missing mods.toml file
# [14:03:23] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.20.1-47.2.20/lowcodelanguage-1.20.1-47.2.20.jar is missing mods.toml file
# [14:03:23] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.20.1-47.2.20/mclanguage-1.20.1-47.2.20.jar is missing mods.toml file
# [14:03:25] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [14:03:25] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: resourcefullib. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/resourcefullib-forge-1.20.1-2.1.23.jar
# [14:03:25] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: expandability. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/expandability-9.0.0.jar
# [14:03:25] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 46 dependencies adding them to mods collection
# [14:03:25] [main/INFO] [or.gr.gm.ma.MappingsProvider/]: Starting runtime mappings setup...
# [14:03:25] [main/INFO] [or.gr.gm.in.lo.ModLocatorInjector/]: Injecting ScriptModLocator candidates...
# [14:03:25] [main/INFO] [or.gr.gm.sc.ScriptModLocator/]: Injected Jimfs file system
# [14:03:25] [main/INFO] [or.gr.gm.sc.ScriptModLocator/]: Skipped loading script mods from directory /workspaces/codespaces-jupyter/Minecraft-server/mods/scripts as it did not exist.
# [14:03:25] [main/INFO] [or.gr.gm.in.lo.ModLocatorInjector/]: Injected ScriptModLocator mod candidates. Found 0 valid mod candidates and 0 broken mod files.
# [14:03:28] [GML Mappings Thread/INFO] [or.gr.gm.ma.MappingsProvider/]: Loaded runtime mappings in 2819ms
# [14:03:28] [GML Mappings Thread/INFO] [or.gr.gm.ma.MappingsProvider/]: Finished runtime mappings setup.
# [14:03:31] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [14:03:31] [main/ERROR] [mixin/]: Mixin config loadingbackgrounds.mixins.json does not specify "minVersion" property
# [14:03:31] [main/ERROR] [mixin/]: Mixin config unpaused.mixins.json does not specify "minVersion" property
# [14:03:31] [main/ERROR] [mixin/]: Mixin config mixins.dangerclose.json does not specify "minVersion" property
# [14:03:32] [main/ERROR] [mixin/]: Mixin config rei-jei-internals-workaround.mixins.json does not specify "minVersion" property
# [14:03:32] [main/ERROR] [mixin/]: Mixin config trimeffects.mixins.json does not specify "minVersion" property
# [14:03:32] [main/ERROR] [mixin/]: Mixin config rei.mixins.json does not specify "minVersion" property
# [14:03:32] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [shetiphian.core.mixins.MixinConnector]
# [14:03:32] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [shetiphian.multibeds.mixins.MixinConnector]
# [14:03:32] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [de.maxhenkel.camera.MixinConnector]
# [14:03:32] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [14:03:32] [main/WARN] [mixin/]: Reference map 'yungsextras.refmap.json' for yungsextras.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'yungsextras.refmap.json' for yungsextras_forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'EpheroLib-refmap.json' for epherolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'untamedwilds.refmap.json' for mixins.untamedwilds.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/INFO] [Puzzles Lib/]: Loading 203 mods:
# 	- additional_lights 2.1.7
# 	- advancementplaques 1.5.1
# 	- alexsmobs 1.22.7
# 	- amendments 1.20-1.1.7
# 	- aquaculture 2.5.1
# 	- aquamirae 6.API15
# 	- architectury 9.2.14
# 	- artifacts 9.3.0
# 	- athena 3.1.1
# 	- attributefix 21.0.4
# 	- automessage 2.2.0
# 	- backpacked 2.2.5
# 	- badpackets 0.4.3
# 	- bagus_lib 1.20.1-4.4.0
# 	- balm 7.2.2
# 	- betterdeserttemples 1.20-Forge-3.0.3
# 	- betterdungeons 1.20-Forge-4.0.3
# 	- betterendisland 1.20-Forge-2.0.5
# 	- betterfortresses 1.20-Forge-2.0.5
# 	- betterjungletemples 1.20-Forge-2.0.4
# 	- bettermineshafts 1.20-Forge-4.0.4
# 	- betteroceanmonuments 1.20-Forge-3.0.4
# 	- betterstrongholds 1.20-Forge-4.0.3
# 	- biomesoplenty 18.0.0.592
# 	- bookshelf 20.1.9
# 	- brutalbosses 1.20.1-6.8
# 	- butchersdelight 1.20.12.0.9
# 	- bygonenether 1.3.2
# 	- camera 1.20.1-1.0.6
# 	- carryon 2.1.2.7
# 	- cataclysm 1.0
# 	- cfm 7.0.0-pre36
# 	- chipped 3.0.4
# 	- chiselsandbits 1.4.147
# 	- citadel 2.5.4
# 	- cloth_config 11.1.118
# 	- collective 7.36
# 	- colourfulearth 1.20.1-2.1
# 	- comforts 6.3.5+1.20.1
# 	- commongroovylibrary 0.3.3
# 	- connectedglass 1.1.11
# 	- cookingforblockheads 16.0.3
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- crabclaws 1.0.0
# 	- craftingtweaks 18.2.3
# 	- crafttweaker 14.0.36
# 	- crashutilities 8.1.4
# 	- create 0.5.1.f
# 	- creativecore 2.11.24
# 	- creeperoverhaul 3.0.2
# 	- croptopia 3.0.4
# 	- cupboard 1.20.1-2.5
# 	- curios 5.7.0+1.20.1
# 	- dangerclose 2.2.4-1.20.1_forge
# 	- darkutils 17.0.3
# 	- decorative_blocks 4.0.2
# 	- disenchanting_table 1.20.1-forge-2.1.0
# 	- doggytalents 1.18.8
# 	- dramaticdoors 1.20.1-3.1.5
# 	- duckling 3.0.0
# 	- dungeoncrawl 2.3.14
# 	- dungeons_arise 2.1.58-1.20.x
# 	- eatanomelette 1.4.0
# 	- eatinganimation 5.0.0
# 	- elevatorid 1.20.1-lex-1.9
# 	- emotecraft 2.2.7-b.build.50
# 	- enderpack 1.20.1-forge-1.0.2
# 	- epherolib 0.1.2
# 	- epicpowerbracelets 1.0.0
# 	- exclusive_weapons_armor_and_tools 2.1.0
# 	- expandability 9.0.0
# 	- eyesinthedarkness 1.3.10
# 	- farmersdelight 1.20.1-1.2.4
# 	- fastbench 8.0.4
# 	- fastfurnace 8.0.1
# 	- fastsuite 5.0.1
# 	- ferritecore 6.0.1
# 	- flywheel 0.6.10-7
# 	- forge 47.2.20
# 	- framedblocks 9.2.0
# 	- framework 0.6.26
# 	- friendsandfoes 2.0.9
# 	- fusion 1.1.1
# 	- geckolib 4.4.2
# 	- gml 4.0.9
# 	- goblintraders 1.9.3
# 	- goldenfoods 2.2.0
# 	- healthywater 1.20.1-forge-1.0.0
# 	- hiddennames 1.20.1-1.0.2
# 	- highlighter 1.1.9
# 	- iceberg 1.1.21
# 	- incapacitated 1.20.1-1.4.4.2
# 	- infernalmobs 1.20.1.2
# 	- iron_ender_chests 1.20-1.0.2
# 	- ironchest 1.20.1-14.4.4
# 	- jade 11.7.1
# 	- jei 15.9999
# 	- journeymap 5.9.18p1
# 	- k_turrets 3.0.21-1.20.1
# 	- konkrete 1.8.0
# 	- kotlinforforge 4.10.0
# 	- loadingbackgrounds 1.1.0
# 	- luckytntlib 46.0.1.4
# 	- luckytntmod 2.3
# 	- macawsbridgesbop 1.20-1.1
# 	- macawsroofsbop 1.20-1.0
# 	- magistuarmory 8.11
# 	- mca 7.5.14+1.20.1
# 	- mcwbridges 2.1.1
# 	- mcwdoors 1.1.0
# 	- mcwfences 1.1.1
# 	- mcwfencesbop 1.20-1.0
# 	- mcwfurnitures 3.2.2
# 	- mcwfurnituresbop 1.20-1.1
# 	- mcwlights 1.0.6
# 	- mcwpaintings 1.0.5
# 	- mcwpaths 1.0.4
# 	- mcwroofs 2.3.0
# 	- mcwtrpdoors 1.1.2
# 	- mcwwindows 2.2.1
# 	- medieval_buildings 1.0.2
# 	- medievalend 1.0.0
# 	- melody 1.0.2
# 	- minecraft 1.20.1
# 	- minetraps 2.3.0
# 	- mixinextras 0.2.0-beta.7
# 	- mixinsquared 0.1.1
# 	- mobdropsrecipes_end 1.0.1
# 	- mobdropsrecipes_nether 1.0.1
# 	- mobdropsrecipes_overworld 1.0.1
# 	- modernlife 1.20.1-1.64
# 	- modonomicon 1.62.0
# 	- monolib 1.0.0
# 	- moonlight 1.20-2.10.10
# 	- morebeautifultorches 2.5.2-1.20.1_forge
# 	- morebowsandarrows 3.0.1
# 	- morevanillaarmor 1.20.1-5.1.2
# 	- moyai 1.20-2.1.4
# 	- multibeds 1.20.1-1.1
# 	- netherskeletons 4.9
# 	- newshieldvariants 1.2.0
# 	- newslabvariants 2.1.0
# 	- obscure_api 15
# 	- obsidianboat 3.1.4
# 	- occultism 1.119.0
# 	- overweight_farming 1.20.1-2.1.0-forge
# 	- paraglider 20.1.3
# 	- patchouli 1.20.1-84-FORGE
# 	- pigpen 15.0.2
# 	- placebo 8.6.1
# 	- playeranimator 1.0.2-rc1+1.20
# 	- plushies 1.4.0
# 	- polymorph 0.49.2+1.20.1
# 	- prism 1.0.5
# 	- puzzlesaccessapi 8.0.7
# 	- puzzleslib 8.1.17
# 	- reap 1.20.1-1.0.2
# 	- rei_plugin_compatibilities 12.0.93
# 	- repurposed_structures 7.1.13+1.20.1-forge
# 	- resourcefulconfig 2.1.2
# 	- resourcefullib 2.1.23
# 	- roughlyenoughitems 12.0.684
# 	- runelic 18.0.2
# 	- satako 7.0.16-1.20.1
# 	- scena 1.0.103
# 	- searchlight 1.1.11
# 	- securitycraft 1.9.8
# 	- shetiphiancore 1.20.1-1.2
# 	- signpost 2.02.0
# 	- skinnedlanterns 1.20.1-1.3.5
# 	- smartbrainlib 1.13
# 	- snowundertrees 1.4.3
# 	- sophisticatedbackpacks 3.20.2.1022
# 	- sophisticatedcore 0.6.7.561
# 	- spectrelib 0.13.15+1.20.1
# 	- stackablestewandsoup 1.3.0
# 	- startinv 1.0.0
# 	- super_ore_block 4.1.0
# 	- supermartijn642configlib 1.1.8
# 	- supermartijn642corelib 1.1.17
# 	- supplementaries 1.20-2.8.6
# 	- terrablender 3.0.1.4
# 	- theurgy 1.17.1
# 	- timeondisplay 2.0.0
# 	- tombstone 8.6.3
# 	- toolbelt 1.20.0
# 	- torchmaster 20.1.5
# 	- trapcraft 2.10.2
# 	- trashslot 15.1.0
# 	- trenzalore 3.3.10
# 	- trimeffects 1.1.1-forge
# 	- tropicraft 9.6.3
# 	- unpaused 1.20.1-forge-1.0.1
# 	- untamedwilds 4.0.4
# 	- usefulbackpacks 2.0.1.122
# 	- uteamcore 5.1.4.269
# 	- visualworkbench 8.0.0
# 	- voicechat 1.20.1-2.4.32
# 	- witherstormmod 4.0.1.1
# 	- xercamod 1.20.1-1.0.0
# 	- yungsapi 1.20-Forge-4.0.4
# 	- yungsbridges 1.20-Forge-4.0.3
# 	- yungsextras 1.20-Forge-4.0.3
# [14:03:32] [main/WARN] [mixin/]: Reference map 'Aquamirae.refmap.json' for aquamirae.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'cookingforblockheads.refmap.json' for cookingforblockheads.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'moyai-forge-refmap.json' for moyai.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'trashslot.refmap.json' for trashslot.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'modonomicon.refmap.json' for modonomicon.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'modonomicon.refmap.json' for modonomicon.forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:32] [main/WARN] [mixin/]: Reference map 'chiselsandbits.refmap.json' for chisels-and-bits.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:03:33] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/ConnectScreen for invalid dist DEDICATED_SERVER
# [14:03:33] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/ConnectScreen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/ConnectScreen for invalid dist DEDICATED_SERVER)
# [14:03:33] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.ConnectScreen was not found loadingbackgrounds.mixins.json:MixinConnectScreen
# [14:03:33] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/ReceivingLevelScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.ReceivingLevelScreen)
# [14:03:33] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.ReceivingLevelScreen was not found loadingbackgrounds.mixins.json:MixinDownloadingTerrainScreen
# [14:03:33] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/LevelLoadingScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.LevelLoadingScreen)
# [14:03:33] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.LevelLoadingScreen was not found loadingbackgrounds.mixins.json:MixinLevelLoadingScreen
# [14:03:33] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/GenericDirtMessageScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.GenericDirtMessageScreen)
# [14:03:33] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.GenericDirtMessageScreen was not found loadingbackgrounds.mixins.json:MixinMessageScreen
# [14:03:33] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/ProgressScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.ProgressScreen)
# [14:03:33] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.ProgressScreen was not found loadingbackgrounds.mixins.json:MixinProgressScreen
# [14:03:33] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/texture/SimpleTexture (java.lang.ClassNotFoundException: net.minecraft.client.renderer.texture.SimpleTexture)
# [14:03:33] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.texture.SimpleTexture was not found loadingbackgrounds.mixins.json:MixinResourceTexture
# [14:03:34] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [14:03:34] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [14:03:34] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [14:03:34] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/Minecraft (java.lang.RuntimeException: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER)
# [14:03:34] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.Minecraft was not found unpaused.mixins.json:MinecraftClientMixin
# [14:03:35] [main/WARN] [mixin/]: Error loading class: vazkii/quark/addons/oddities/inventory/BackpackMenu (java.lang.ClassNotFoundException: vazkii.quark.addons.oddities.inventory.BackpackMenu)
# [14:03:35] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/inventory/CraftingScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.inventory.CraftingScreen)
# [14:03:35] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.inventory.CraftingScreen was not found fastbench.mixins.json:MixinCraftingScreen
# [14:03:36] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.2.1).
# [14:03:37] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [14:03:37] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [14:03:40] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [14:03:40] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [14:03:43] [main/WARN] [mixin/]: @Inject(@At("INVOKE")) Shift.BY=2 on witherstormmod.mixins.json:MixinSwellGoal::handler$bah000$canUseInvoke exceeds the maximum allowed value: 0. Increase the value of maxShiftBy to suppress this warning.
# [14:03:54] [main/INFO] [or.gr.gm.in.ModExtensionLoader/]: Skipping extension class org.groovymc.cgl.api.extension.client.MinecraftExtensions: it requires dist CLIENT, but we're running on DEDICATED_SERVER
# [14:03:54] [modloading-worker-0/INFO] [satako/]: Satako loaded
# [14:03:54] [modloading-worker-0/INFO] [scena-forge/]: Initialized scena-forge
# [14:03:55] [modloading-worker-0/INFO] [gml/]: Initialised GML mod. Version: 4.0.9
# [14:03:56] [modloading-worker-0/INFO] [EatAnOmelette/]: Hello Forge world!
# [14:03:56] [modloading-worker-0/INFO] [EatAnOmelette/]: Hello from EatAnOmelette Common init on Forge! we are currently in a production environment!
# [14:03:56] [modloading-worker-0/INFO] [EatAnOmelette/]: The ID for diamonds is minecraft:diamond
# [14:03:56] [modloading-worker-0/INFO] [EatAnOmelette/]: Hello to EatAnOmelette
# [14:03:56] [modloading-worker-0/INFO] [StackableStewAndSoup/]: Hello Forge world!
# [14:03:56] [modloading-worker-0/INFO] [StackableStewAndSoup/]: Hello from StackableStewAndSoup Common init on Forge! we are currently in a production environment!
# [14:03:56] [modloading-worker-0/INFO] [StackableStewAndSoup/]: The ID for diamonds is minecraft:diamond
# [14:03:56] [modloading-worker-0/INFO] [StackableStewAndSoup/]: Hello to StackableStewAndSoup
# [14:03:57] [modloading-worker-0/INFO] [TimeOnDisplay/]: Hello Forge world!
# [14:03:57] [modloading-worker-0/INFO] [TimeOnDisplay/]: Hello from TimeOnDisplay Common init on Forge! we are currently in a production environment!
# [14:03:57] [modloading-worker-0/INFO] [TimeOnDisplay/]: The ID for diamonds is minecraft:diamond
# [14:03:57] [modloading-worker-0/INFO] [TimeOnDisplay/]: Hello to TimeOnDisplay
# [14:03:57] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for visualworkbench:main
# [14:03:57] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [14:03:57] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v47.2.20 Initialized
# [14:03:57] [modloading-worker-0/INFO] [un.UntamedWilds/]: Loading compatibility module with Patchouli
# [14:03:58] [modloading-worker-0/INFO] [th.ko.te.KotlinForForge/]: Kotlin For Forge Enabled!
# [14:03:58] [modloading-worker-0/INFO] [co.ep.ep.co.CommonConfig/]: Creating default config file: croptopia_v3.conf
# [14:03:58] [modloading-worker-0/INFO] [NewSlabVariants/]: Hello Forge world!
# [14:03:58] [modloading-worker-0/INFO] [NewSlabVariants/]: Hello from NewSlabVariants Common init on Forge! we are currently in a production environment!
# [14:03:58] [modloading-worker-0/INFO] [NewSlabVariants/]: The ID for diamonds is minecraft:diamond
# [14:03:58] [modloading-worker-0/INFO] [NewSlabVariants/]: Hello to NewSlabVariants
# [14:03:59] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for puzzleslib:main
# [14:03:59] [modloading-worker-0/INFO] [fr.sa.mc.McwFurnituresBOP/]: Macaw's Furnitures - Biome O' Plenty : Loading...
# [14:03:59] [modloading-worker-0/INFO] [fr.sa.mc.McwFurnituresBOP/]: Macaw's Furnitures - Biome O' Plenty : Is Charged
# [14:03:59] [modloading-worker-0/INFO] [NewShieldVariants/]: Hello Forge world!
# [14:04:00] [modloading-worker-0/INFO] [NewShieldVariants/]: Hello from NewShieldVariants Common init on Forge! we are currently in a production environment!
# [14:04:00] [modloading-worker-0/INFO] [NewShieldVariants/]: The ID for diamonds is minecraft:diamond
# [14:04:00] [modloading-worker-0/INFO] [NewShieldVariants/]: Hello to NewShieldVariants
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [14:04:00] [modloading-worker-0/INFO] [in.u_.u_.ut.ve.JarSignVerifier/]: Mod uteamcore is signed with a valid certificate.
# [14:04:00] [modloading-worker-0/INFO] [de.ke.me.Melody/]: [MELODY] Disabling Melody since it's loaded server-side.
# [14:04:00] [modloading-worker-0/INFO] [fr.sa.ma.MacawsRoofsBOP/]: Macaw's Roofs - Biome O' Plenty : Loading...
# [14:04:00] [modloading-worker-0/INFO] [fr.sa.ma.MacawsRoofsBOP/]: Macaw's Roofs - Biome O' Plenty : Is Charged
# [14:04:00] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Successfully initialized!
# [14:04:00] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Server-side libs ready to use!
# [14:04:00] [modloading-worker-0/INFO] [fr.sa.ma.MacawsBridgesBOP/]: Macaw's Bridges - Biome O' Plenty : Loading ...
# [14:04:00] [modloading-worker-0/INFO] [fr.sa.ma.MacawsBridgesBOP/]: Macaw's Bridges - Biome O' Plenty : Is Charged
# [14:04:00] [modloading-worker-0/INFO] [in.u_.u_.ut.ve.JarSignVerifier/]: Mod usefulbackpacks is signed with a valid certificate.
# [14:04:00] [modloading-worker-0/INFO] [fr.sa.mc.McwFencesBOP/]: Macaw's Fences - Biome O' Plenty : Loading ...
# [14:04:00] [modloading-worker-0/INFO] [fr.sa.mc.McwFencesBOP/]: Macaw's Fences - Biome O' Plenty : Is Charged
# [14:04:00] [modloading-worker-0/INFO] [MobDropsRecipes End/]: Hello Forge world!
# [14:04:00] [modloading-worker-0/INFO] [MobDropsRecipes End/]: Hello from MobDropsRecipes End Common init on Forge! we are currently in a production environment!
# [14:04:00] [modloading-worker-0/INFO] [MobDropsRecipes End/]: The ID for diamonds is minecraft:diamond
# [14:04:00] [modloading-worker-0/INFO] [MobDropsRecipes End/]: Hello to MobDropsRecipes End
# [14:04:01] [modloading-worker-0/INFO] [Collective/]: Loading Collective version 7.36.
# [14:04:01] [modloading-worker-0/INFO] [GoldenFoods/]: Hello Forge world!
# [14:04:01] [modloading-worker-0/INFO] [GoldenFoods/]: Hello from GoldenFoods Common init on Forge! we are currently in a production environment!
# [14:04:01] [modloading-worker-0/INFO] [GoldenFoods/]: The ID for diamonds is minecraft:diamond
# [14:04:01] [modloading-worker-0/INFO] [GoldenFoods/]: Hello to GoldenFoods
# [14:04:01] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [14:04:01] [modloading-worker-0/INFO] [MonoLib/]: Hello Forge world!
# [14:04:01] [modloading-worker-0/INFO] [MonoLib/]: Hello from MonoLib Common init on Forge! we are currently in a production environment!
# [14:04:01] [modloading-worker-0/INFO] [MonoLib/]: The ID for diamonds is minecraft:diamond
# [14:04:01] [modloading-worker-0/INFO] [MonoLib/]: Hello to MonoLib
# [14:04:01] [modloading-worker-0/INFO] [co.cu.Cupboard/]: Loaded config for: cupboard.json
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Nether/]: Hello Forge world!
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Nether/]: Hello from MobDropsRecipes Nether Common init on Forge! we are currently in a production environment!
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Nether/]: The ID for diamonds is minecraft:diamond
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Nether/]: Hello to MobDropsRecipes Nether
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Overworld/]: Hello Forge world!
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Overworld/]: Hello from MobDropsRecipes Overworld Common init on Forge! we are currently in a production environment!
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Overworld/]: The ID for diamonds is minecraft:diamond
# [14:04:01] [modloading-worker-0/INFO] [MobDropsRecipes Overworld/]: Hello to MobDropsRecipes Overworld
# [14:04:01] [modloading-worker-0/ERROR] [ne.mi.ev.EventSubclassTransformer/EVENTBUS]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@102af1bb on thread Thread[#36,modloading-worker-0,5,main]
# [14:04:01] [modloading-worker-0/ERROR] [ne.mi.ev.EventSubclassTransformer/EVENTBUS]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:141) ~[securejarhandler-2.1.10.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar%2352!/:?] {}
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar%2352!/:?] {}
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar%2352!/:?] {}
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar%2352!/:6.0.5+6.0.5+master.eb8e549b] {}
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar%2355!/:?] {}
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar%2355!/:?] {}
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar%2355!/:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:113) ~[securejarhandler-2.1.10.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:219) ~[securejarhandler-2.1.10.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:229) ~[securejarhandler-2.1.10.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:219) ~[securejarhandler-2.1.10.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:135) ~[securejarhandler-2.1.10.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?] {}
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?] {}
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?] {}
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?] {}
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?] {}
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?] {re:mixin}
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?] {}
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?] {}
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23423!/:com.obscuria] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:28) ~[obscure_api-15.jar%23423!/:com.obscuria] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:46) ~[obscure_api-15.jar%23423!/:com.obscuria] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:69) ~[obscure_api-15.jar%23423!/:com.obscuria] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?] {}
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?] {}
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?] {}
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:70) ~[javafmllanguage-1.20.1-47.2.20.jar%23489!/:?] {}
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$4(ModContainer.java:124) ~[fmlcore-1.20.1-47.2.20.jar%23488!/:?] {}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) ~[?:?] {}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) ~[?:?] {}
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) ~[?:?] {}
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) ~[?:?] {}
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) ~[?:?] {re:computing_frames,pl:rei_plugin_compatibilities:B}
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) ~[?:?] {re:computing_frames,pl:rei_plugin_compatibilities:B}
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) ~[?:?] {}
# [14:04:01] [modloading-worker-0/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [14:04:01] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [14:04:01] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [14:04:01] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [14:04:01] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [14:04:01] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [14:04:01] [modloading-worker-0/INFO] [Dungeon Crawl/]: Here we go! Launching Dungeon Crawl 2.3.14...
# [14:04:02] [modloading-worker-0/INFO] [AutoMessage/]: Hello Forge world!
# [14:04:02] [modloading-worker-0/INFO] [AutoMessage/]: Hello from AutoMessage Common init on Forge! we are currently in a production environment!
# [14:04:02] [modloading-worker-0/INFO] [AutoMessage/]: The ID for diamonds is minecraft:diamond
# [14:04:02] [modloading-worker-0/INFO] [AutoMessage/]: Hello to AutoMessage
# [14:04:02] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id magistuarmory:packet_long_reach_attack
# [14:04:02] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id magistuarmory:packet_lance_collision
# [14:04:02] [modloading-worker-0/INFO] [MoreBowsAndArrows/]: Hello Forge world!
# [14:04:02] [modloading-worker-0/INFO] [MoreBowsAndArrows/]: Hello from MoreBowsAndArrows Common init on Forge! we are currently in a production environment!
# [14:04:02] [modloading-worker-0/INFO] [MoreBowsAndArrows/]: The ID for diamonds is minecraft:diamond
# [14:04:02] [modloading-worker-0/INFO] [MoreBowsAndArrows/]: Hello to MoreBowsAndArrows
# [14:04:02] [ForkJoinPool.commonPool-worker-1/INFO] [friendsandfoes/]: [Friends&Foes] An update is available! You are using 2.0.9 version, but the latest version is 2.0.10.
# [14:04:02] [modloading-worker-0/INFO] [be.fl.ex.ExpandAbility/]: ExpandAbility here, who dis?
# [14:04:02] [modloading-worker-0/INFO] [mo.ch.fo.Forge/]: Initialized Chisels&Bits - Forge
# [14:04:02] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:request_tags_c2s
# [14:04:02] [modloading-worker-0/INFO] [REI/]: [REI] Registered plugin provider DefaultPluginImpl [roughlyenoughitems] for REIServerPlugin
# [14:04:02] [modloading-worker-0/INFO] [REI/]: [REI] Registered plugin provider DefaultPluginImpl [roughlyenoughitems] for REIPlugin
# [14:04:03] [modloading-worker-0/INFO] [REI/]: [REI] Registered plugin provider DefaultRuntimePlugin [roughlyenoughitems] for REIServerPlugin
# [14:04:03] [modloading-worker-0/INFO] [REI/]: [REI] Registered plugin provider DefaultRuntimePlugin [roughlyenoughitems] for REIPlugin
# [14:04:03] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:delete_item
# [14:04:03] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:create_item
# [14:04:03] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:create_item_grab
# [14:04:03] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:create_item_hotbar
# [14:04:03] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:move_items
# [14:04:03] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id roughlyenoughitems:move_items_new
# [14:04:03] [modloading-worker-0/INFO] [mo.ch.re.ModBlockEntityTypes/]: Loaded block entity configuration.
# [14:04:03] [modloading-worker-0/INFO] [mo.ch.re.ModBlocks/]: Loaded block configuration.
# [14:04:03] [modloading-worker-0/INFO] [mo.ch.re.ModChiselModeGroups/]: Loaded chisel mode group configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModChiselModes/]: Loaded chisel mode configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModContainerTypes/]: Loaded container type configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModCreativeTabs/]: Loaded item group configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModItems/]: Loaded item configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModMetadataKeys/]: Loaded metadata key configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModModelProperties/]: Loaded model property configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModModificationOperation/]: Loaded modification operation configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModModificationOperationGroups/]: Loaded modification operation group configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModPatternPlacementTypes/]: Loaded pattern placement type configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModRecipeSerializers/]: Loaded recipe serializer configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModTags/]: Loaded tag configuration.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModRecipeTypes/]: Registering recipe types.
# [14:04:04] [modloading-worker-0/INFO] [mo.ch.re.ModEventHandler/]: Registering event handlers
# [14:04:09] [main/INFO] [Moonlight/]: Initialized block sets in 66ms
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_iron_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_iron_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_acacia_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_acacia_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_dark_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_dark_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_mangrove_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_mangrove_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_cherry_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_cherry_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bamboo_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bamboo_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_crimson_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_crimson_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_warped_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_warped_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_dead_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_dead_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_fir_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_fir_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_hellbark_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_hellbark_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_jacaranda_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_jacaranda_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_magic_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_magic_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_mahogany_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_mahogany_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_palm_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_palm_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_redwood_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_redwood_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_umbran_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_umbran_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_bop_willow_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_bop_willow_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_gold_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_silver_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_lead_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: short_netherite_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_gold_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_silver_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_lead_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_netherite_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_heavy_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_dual_paneled_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_pressed_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_shack_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_sliding_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_screen_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_gated_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_glass_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_windowed_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tiled_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tile_windowed_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_fortified_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_secret_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_boarded_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_paper_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_beach_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_barred_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_paneled_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_supported_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_overgrown_oak_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_heavy_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_dual_paneled_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_pressed_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_shack_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_sliding_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_screen_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_gated_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_glass_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_windowed_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tiled_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tile_windowed_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_fortified_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_secret_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_modern_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_paper_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_beach_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_barred_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_paneled_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_supported_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_overgrown_spruce_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_heavy_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_dual_paneled_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_pressed_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_shack_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_sliding_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_screen_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_gated_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_glass_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_windowed_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tiled_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tile_windowed_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_fortified_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_secret_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_modern_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_boarded_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_beach_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_barred_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_paneled_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_supported_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_overgrown_birch_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_heavy_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_dual_paneled_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_pressed_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_shack_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_sliding_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_screen_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_gated_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_glass_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_windowed_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tiled_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_tile_windowed_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_fortified_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_secret_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_modern_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_boarded_jungle_door
# [14:04:10] [main/INFO] [dramaticdoors/]: Registering item: tall_chipped_paper_jungle_door
# ...
# 	at net.minecraft.server.level.ChunkTaskPriorityQueueSorter.m_143188_(ChunkTaskPriorityQueueSorter.java:62) ~[server-1.20.1-20230612.114412-srg.jar%23487!/:?] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at net.minecraft.util.thread.ProcessorMailbox.m_18759_(ProcessorMailbox.java:91) ~[server-1.20.1-20230612.114412-srg.jar%23487!/:?] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at net.minecraft.util.thread.ProcessorMailbox.m_18747_(ProcessorMailbox.java:146) ~[server-1.20.1-20230612.114412-srg.jar%23487!/:?] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at net.minecraft.util.thread.ProcessorMailbox.run(ProcessorMailbox.java:102) ~[server-1.20.1-20230612.114412-srg.jar%23487!/:?] {re:classloading,pl:rei_plugin_compatibilities:B}
# 	at java.util.concurrent.ForkJoinTask$RunnableExecuteAction.exec(ForkJoinTask.java:1423) ~[?:?] {}
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) ~[?:?] {}
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) ~[?:?] {}
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) ~[?:?] {re:computing_frames,pl:rei_plugin_compatibilities:B}
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) ~[?:?] {re:computing_frames,pl:rei_plugin_compatibilities:B}
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) ~[?:?] {}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:23:23] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: BhackenovPlays moved wrongly!
# [16:26:03] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo has reached the goal [Bone Crusher]
# [16:27:01] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: BhackenovPlays moved too quickly! -8.996243325365185,1.4524514780759716,-4.203952702650668
# [16:27:21] [Worker-Main-42/ERROR] [minecraft/Util]: Detected setBlock in a far chunk [-120, 40], pos: BlockPos{x=-1913, y=62, z=653}, status: minecraft:features, currently generating: Placed Direct{Configured: untamedwilds.world.gen.feature.FeatureReedClusters@57a5f6f: net.minecraft.world.level.levelgen.feature.configurations.NoneFeatureConfiguration@2ec61ce7}
# [16:27:40] [pool-9-thread-2/INFO] [Supplementaries/]: Searching for closest structure among [ResourceKey[minecraft:worldgen/structure / minecraft:village_snowy], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_jungle], ResourceKey[minecraft:worldgen/structure / minecraft:village_desert], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_dark_forest], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_crimson], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_swamp], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_oak], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_cherry]] from pos BlockPos{x=-1765, y=67, z=747}
# [16:27:43] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2160ms or 43 ticks behind
# [16:27:43] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Frannciisscoo moved too quickly! -0.42978663258099914,2.0931984815392486,-10.122194872615808
# [16:28:54] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: BhackenovPlays moved too quickly! -5.02360912211725,-9.699661918294325,1.2104395945174247
# [16:28:55] [Server thread/INFO] [minecraft/MinecraftServer]: BhackenovPlays is incapacitated!
# [16:28:55] [Server thread/WARN] [tombstone/]: The death event of the player BhackenovPlays was canceled by another mod
# [16:28:55] [Server thread/INFO] [tombstone/]: The player BhackenovPlays has successfully been saved
# [16:29:19] [Server thread/INFO] [minecraft/MinecraftServer]: BhackenovPlays withered away whilst fighting Zombie
# [16:29:19] [Server thread/INFO] [tombstone/]: The player BhackenovPlays has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [16:29:21] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [16:32:41] [pool-9-thread-3/INFO] [Supplementaries/]: Searching for closest structure among [ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_jungle], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_badlands], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_crimson], ResourceKey[minecraft:worldgen/structure / minecraft:village_taiga], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_ocean], ResourceKey[minecraft:worldgen/structure / minecraft:village_desert], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_swamp], ResourceKey[minecraft:worldgen/structure / repurposed_structures:village_oak]] from pos BlockPos{x=-1995, y=74, z=437}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:34:20] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo has made the advancement [Chest Slayer]
# [16:38:16] [Worker-Main-26/ERROR] [minecraft/Util]: Detected setBlock in a far chunk [-130, 46], pos: BlockPos{x=-2068, y=60, z=749}, status: minecraft:features, currently generating: Placed Direct{Configured: untamedwilds.world.gen.feature.FeatureReedClusters@57a5f6f: net.minecraft.world.level.levelgen.feature.configurations.NoneFeatureConfiguration@2ec61ce7}
# [16:38:16] [Worker-Main-26/ERROR] [minecraft/Util]: Detected setBlock in a far chunk [-130, 46], pos: BlockPos{x=-2070, y=60, z=751}, status: minecraft:features, currently generating: Placed Direct{Configured: untamedwilds.world.gen.feature.FeatureReedClusters@57a5f6f: net.minecraft.world.level.levelgen.feature.configurations.NoneFeatureConfiguration@2ec61ce7}
# [16:39:15] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: BhackenovPlays moved too quickly! -2.5978170258831597,-9.667067244575911,3.57872108565482
# [16:40:18] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [16:40:18] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [16:40:18] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [16:41:31] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo has been revived!
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:44:08] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [16:44:08] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [16:44:08] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [16:44:14] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo hit the ground too hard and bled out
# [16:44:14] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [16:44:15] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [16:46:08] [Server thread/INFO] [minecraft/MinecraftServer]: BhackenovPlays has made the advancement [Diamonds!]
# [16:46:43] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [16:46:43] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [16:46:43] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [16:47:00] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo was blown up by Creeper
# [16:47:00] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [16:47:01] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [16:49:50] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [16:49:50] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [16:49:50] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [16:50:27] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo has been revived!
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:53:39] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [16:53:39] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [16:53:39] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [16:54:14] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo was shot by Skeleton and bled out
# [16:54:14] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [16:54:15] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [16:55:35] [Server thread/INFO] [minecraft/Villager]: Villager VillagerEntityMCA['Vratislav'/84280, l='ServerLevel[world]', x=-2101.57, y=58.00, z=662.54] died, message: 'Vratislav hit the ground too hard'
# [16:55:35] [Server thread/INFO] [minecraft/LivingEntity]: Named entity VillagerEntityMCA['Vratislav'/84280, l='ServerLevel[world]', x=-2101.57, y=58.00, z=662.54] died: Vratislav was doomed to fall
# [16:57:15] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [16:57:15] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [16:57:15] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [16:57:31] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo was slain by Zombie
# [16:57:31] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [16:57:32] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [16:58:06] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo has made the advancement [Your First Receptacle]
# [17:01:29] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo withered away whilst fighting Zombie
# [17:01:29] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [17:01:37] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [17:02:21] [Server thread/INFO] [minecraft/MinecraftServer]: BhackenovPlays is incapacitated!
# [17:02:21] [Server thread/WARN] [tombstone/]: The death event of the player BhackenovPlays was canceled by another mod
# [17:02:21] [Server thread/INFO] [tombstone/]: The player BhackenovPlays has successfully been saved
# [17:02:54] [Server thread/INFO] [minecraft/MinecraftServer]: [Not Secure] <Frannciisscoo> Se desconecto el discord
# [17:02:57] [Server thread/INFO] [minecraft/MinecraftServer]: BhackenovPlays drowned and bled out
# [17:02:57] [Server thread/INFO] [tombstone/]: The player BhackenovPlays has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [17:02:59] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [17:03:21] [Server thread/INFO] [minecraft/MinecraftServer]: [Not Secure] <Frannciisscoo> Se te cerro el discord
# [17:04:06] [Server thread/INFO] [minecraft/MinecraftServer]: [Not Secure] <BhackenovPlays> mi juego tiene problemas con el discord
# [17:06:47] [Server thread/INFO] [minecraft/MinecraftServer]: [Not Secure] <BhackenovPlays> configura el chat de voz de aqui
# [17:09:38] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [17:09:38] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [17:09:38] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [17:10:15] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: BhackenovPlays lost connection: Disconnected
# [17:10:15] [Server thread/INFO] [minecraft/MinecraftServer]: BhackenovPlays left the game
# [17:10:15] [Server thread/INFO] [voicechat/]: [voicechat] Disconnecting client BhackenovPlays
# [17:10:46] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo was slain by Zombie and bled out
# [17:10:46] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [17:10:48] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# [17:11:19] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo is incapacitated!
# [17:11:19] [Server thread/WARN] [tombstone/]: The death event of the player Frannciisscoo was canceled by another mod
# [17:11:19] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# [17:11:28] [Server thread/INFO] [minecraft/MinecraftServer]: Frannciisscoo was blown up by Creeper and bled out
# [17:11:28] [Server thread/INFO] [tombstone/]: The player Frannciisscoo has successfully been saved
# > onPlayerCloned
# isWasDeath
# ifPresent1
# ifPresent2
# [17:11:29] [Server thread/WARN] [de.gi.to.sl.BeltExtensionSlot/]: New entity has data, contents assigned.
# >
